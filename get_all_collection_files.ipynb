# %%
#shortcut to download select collections from cellxgene
#clone repo https://github.com/chanzuckerberg/single-cell-curation.git
#to run this, cd to single-cell-curation/notebooks/curation-api/python/

from src.dataset import (
    download_assets,
    get_dataset,   
)

from src.collection import (
get_collection
)

from src.utils.config import set_api_access_config
set_api_access_config()

#replace colluction_uuid with desired uuid(s)
collection_ids=['283d65eb-dd53-496d-adb7-7570c7caa443']

#initialize empy list for 'collections', which we will pass to get_dataset to get download links
#see curation-api/python/src/dataset.py for reference
collections=[]
datasets=[]

for id in collection_ids:
    collection = get_collection(id)
    collections.append(collection)
    
#print(collections)
    

#iterate through collections list and get dataset object, which contains download links we will pass to download_assets
#see src/dataset.py for source code
for item in collections:
    for dataset in item['datasets']:
        datasets.append(get_dataset(item['collection_id'],dataset['dataset_id']))
      
#download all h5ad and rds files for given collections
download_assets(datasets)
# Out:
# Set 'SITE_URL' env var to https://cellxgene.cziscience.com
# Set 'API_URL_BASE' env var to https://api.cellxgene.cziscience.com
# No API key file provided. Without an access token, which requires an API key to retrieve, no private data or actions are accessible (except for fetching an individual Collection or Dataset, which only requires the url).
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
# No access token included in request
#
# Downloading ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded.H5AD...
# 100.0% downloaded
# Downloading ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded.RDS...
# 100.0% downloaded
# Downloading fe1a73ab-a203-45fd-84e9-0f7fd19efcbd.H5AD...
# 100.0% downloaded
# Downloading fe1a73ab-a203-45fd-84e9-0f7fd19efcbd.RDS...
# 100.0% downloaded
# Downloading fbf173f9-f809-4d84-9b65-ae205d35b523.H5AD...
# 100.0% downloaded
# Downloading fbf173f9-f809-4d84-9b65-ae205d35b523.RDS...
# 100.0% downloaded
# Downloading fa554686-fc07-44dd-b2de-b726d82d26ec.H5AD...
# 100.0% downloaded
# Downloading fa554686-fc07-44dd-b2de-b726d82d26ec.RDS...
# 100.0% downloaded
# Downloading f9034091-2e8f-4ac6-9874-e7b7eb566824.H5AD...
# 100.0% downloaded
# Downloading f9034091-2e8f-4ac6-9874-e7b7eb566824.RDS...
# 100.0% downloaded
# Downloading f8dda921-5fb4-4c94-a654-c6fc346bfd6d.H5AD...
# 100.0% downloaded
# Downloading f8dda921-5fb4-4c94-a654-c6fc346bfd6d.RDS...
# 100.0% downloaded
# Downloading f7d003d4-40d5-4de8-858c-a9a8b48fcc67.H5AD...
# 100.0% downloaded
# Downloading f7d003d4-40d5-4de8-858c-a9a8b48fcc67.RDS...
# 100.0% downloaded
# Downloading f6d9f2ad-5ec7-4d53-b7f0-ceb0e7bcd181.H5AD...
# 100.0% downloaded
# Downloading f6d9f2ad-5ec7-4d53-b7f0-ceb0e7bcd181.RDS...
# 100.0% downloaded
# Downloading f5a04dff-d394-4023-8811-65494e8bb11d.H5AD...
# 100.0% downloaded
# Downloading f5a04dff-d394-4023-8811-65494e8bb11d.RDS...
# 100.0% downloaded
# Downloading f502c312-05dc-4fd4-a762-92a63e92b539.H5AD...
# 100.0% downloaded
# Downloading f502c312-05dc-4fd4-a762-92a63e92b539.RDS...
# 100.0% downloaded
# Downloading f3565fda-499a-4d20-bd92-563c09954c42.H5AD...
# 100.0% downloaded
# Downloading f3565fda-499a-4d20-bd92-563c09954c42.RDS...
# 100.0% downloaded
# Downloading f32c2c13-bb1a-4ffd-a457-60b64ecfa4cb.H5AD...
# 4.6% downloaded
